# %% [markdown]
# # Statistics Assignment Solutions (Distribution + Correlation)

# %% [markdown]
# ## Distribution Section

# %% [markdown]
# Q1 Excel: =BINOM.DIST(5,30,1/6,FALSE)

# %%
from math import comb
n,x,p=30,5,1/6
comb(n,x)*(p**x)*((1-p)**(n-x))

# %% [markdown]
# Q2 Uniform Distribution Histogram

# %%
import numpy as np
import matplotlib.pyplot as plt
data=np.random.rand(100)
plt.hist(data,bins=10)
plt.show()

# %% [markdown]
# Q3: ~68% rule

# %% [markdown]
# Q4: Z=(X-μ)/σ

# %% [markdown]
# Q5: Kurtosis types

# %% [markdown]
# Q6: Dice = uniform

# %% [markdown]
# Q7 Excel: =1-BINOM.DIST(7,15,0.5,TRUE)

# %%
from scipy.stats import binom
1-binom.cdf(7,15,0.5)

# %% [markdown]
# Q8: Log transformation reduces skew

# %% [markdown]
# ## Correlation Section

# %% [markdown]
# Q1: Covariance vs Correlation

# %% [markdown]
# Q2: Positive/Negative/Zero

# %% [markdown]
# Q3: Limitation of covariance

# %% [markdown]
# Q4: Pearson vs Spearman

# %% [markdown]
# Q5: r=0.85 strong positive

# %% [markdown]
# Q6: Covariance

# %%
import numpy as np
X=np.array([2,4,6,8])
Y=np.array([3,7,5,10])
np.cov(X,Y)[0,1]

# %% [markdown]
# Q7: Correlation

# %%
A=np.array([10,20,30,40])
B=np.array([8,14,18,24])
np.corrcoef(A,B)[0,1]

# %% [markdown]
# Q8: Height Weight

# %%
H=np.array([150,160,165,170,180])
W=np.array([50,55,58,62,70])
np.corrcoef(H,W)[0,1]

# %% [markdown]
# Q9: Negative correlation

# %% [markdown]
# Q10: Portfolio

# %%
A=np.array([6,10,12,9,11])
B=np.array([9,11,8,10,10])
np.cov(A,B)[0,1], np.corrcoef(A,B)[0,1]
